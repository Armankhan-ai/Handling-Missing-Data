# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\arman\Downloads\Pixar+Films\public_response.csv")
dataset.head(4)
# Out:
#              film  rotten_tomatoes_score  rotten_tomatoes_counts  \
# 0       Toy Story                    100                      96
# 1    A Bug's Life                     92                      91
# 2     Toy Story 2                    100                     172
# 3  Monsters, Inc.                     96                     199
#
#    metacritic_score  metacritic_counts cinema_score  imdb_score  imdb_counts
# 0                95                 26            A         8.3      1089101
# 1                78                 23            A         7.2       319596
# 2                88                 34           A+         7.9       630573
# 3                79                 35           A+         8.1      1000657

# %%
dataset.shape
# Out:
# (28, 8)

# %%
dataset.isnull().sum()
# Out:
# film                      0
# rotten_tomatoes_score     0
# rotten_tomatoes_counts    0
# metacritic_score          0
# metacritic_counts         0
# cinema_score              3
# imdb_score                0
# imdb_counts               0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
# Drop the null values columns or rows
dataset.drop(columns=["cinema_score"],inplace=True)

# %%
dataset.shape
# Out:
# (28, 7)

# %%
sns.heatmap(dataset.isnull())
plt.show()
